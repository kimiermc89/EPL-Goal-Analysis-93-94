# %%
# Hi all, welcome to my humble notebook
# In order to make it nice, this analysis will present to you
# in a story telling format.

# EPL or English Premier League are a most watch sports show
# in the whole world.

# Fans from around the world love every match from EPL and
# cant wait to see their favourite team match every weekend.

# This analysis will contains some input on Home winning and 
# Away winning from 1993 till 2018

# Dataset that we are going to use name as "epl-results-1993-2018"

# Sit back and relax, watch my story below and feel each of its.

# Thanks and please upvote my notebook analysis if you like it.

# %%
# before we start, i need to import several things in order
# for me to enjoy and story my analysis

import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

print("Setup Complete")
# Out:
# Setup Complete

# %%
# This is a code to load my file into notebook
epl_filepath = "../input/epl-results-19932018/EPL_Set.csv"

# After i load, for sure i need it to be read, so i use pandas to help me read it.
epl_data = pd.read_csv(epl_filepath)

# %%
# After i load, i need to see what pandas already read for me
# In order for me to understand what i have here. I will print
# it into format that we all can unserstand.

epl_data.head()
# Out:
#   Div      Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR  \
# 0  E0  14/08/93      Arsenal        Coventry     0     3   A   NaN   NaN  NaN
# 1  E0  14/08/93  Aston Villa             QPR     4     1   H   NaN   NaN  NaN
# 2  E0  14/08/93      Chelsea       Blackburn     1     2   A   NaN   NaN  NaN
# 3  E0  14/08/93    Liverpool  Sheffield Weds     2     0   H   NaN   NaN  NaN
# 4  E0  14/08/93     Man City           Leeds     1     1   D   NaN   NaN  NaN
#
#     Season
# 0  1993-94
# 1  1993-94
# 2  1993-94
# 3  1993-94
# 4  1993-94

# %%
# Up there in the table you all can see that we have several 
# columns and rows determined by date of each EPL match
# As you can see, the most important column is a "Home Team"
# and "Away Team".

# Now we need to see till when this table go and what we have 
# in the bottom of the table/dataset

epl_data.tail()
# Out:
#      Div      Date     HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 9659  E0  13/05/18    Newcastle    Chelsea     3     0   H   1.0   0.0   H
# 9660  E0  13/05/18  Southampton   Man City     0     1   A   0.0   0.0   D
# 9661  E0  13/05/18      Swansea      Stoke     1     2   A   1.0   2.0   A
# 9662  E0  13/05/18    Tottenham  Leicester     5     4   H   1.0   2.0   A
# 9663  E0  13/05/18     West Ham    Everton     3     1   H   1.0   0.0   H
#
#        Season
# 9659  2017-18
# 9660  2017-18
# 9661  2017-18
# 9662  2017-18
# 9663  2017-18

# %%
# After table load you can see our data is till 13 May 2018
# and the last match is between "West Ham vs Everton".
# Unfortunately 2018 last match Everton lost "hahahaha"

# Now we are gonna start to query some insigts from this table.

epl_data
# Out:
#      Div      Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0     E0  14/08/93      Arsenal        Coventry     0     3   A   NaN   NaN
# 1     E0  14/08/93  Aston Villa             QPR     4     1   H   NaN   NaN
# 2     E0  14/08/93      Chelsea       Blackburn     1     2   A   NaN   NaN
# 3     E0  14/08/93    Liverpool  Sheffield Weds     2     0   H   NaN   NaN
# 4     E0  14/08/93     Man City           Leeds     1     1   D   NaN   NaN
# ...   ..       ...          ...             ...   ...   ...  ..   ...   ...
# 9659  E0  13/05/18    Newcastle         Chelsea     3     0   H   1.0   0.0
# 9660  E0  13/05/18  Southampton        Man City     0     1   A   0.0   0.0
# 9661  E0  13/05/18      Swansea           Stoke     1     2   A   1.0   2.0
# 9662  E0  13/05/18    Tottenham       Leicester     5     4   H   1.0   2.0
# 9663  E0  13/05/18     West Ham         Everton     3     1   H   1.0   0.0
#
#       HTR   Season
# 0     NaN  1993-94
# ...

# %%
# This EPL dataset contains of 9664 rows and that means we have 9664 date of match in this 
# entire dataset. OMG thats a lot.

epl_data.Date

# We will analyst all data by year and it will required more time for me to process.
# Out:
# 0       14/08/93
# 1       14/08/93
# 2       14/08/93
# 3       14/08/93
# 4       14/08/93
#           ...
# 9659    13/05/18
# 9660    13/05/18
# 9661    13/05/18
# 9662    13/05/18
# 9663    13/05/18
# Name: Date, Length: 9664, dtype: object

# %%
# We start analyst season 93/94 match
# Hope we are gonna find something interesting. Lets begin!!!

epl_data.iloc[0]
# Out:
# Div               E0
# Date        14/08/93
# HomeTeam     Arsenal
# AwayTeam    Coventry
# FTHG               0
# FTAG               3
# FTR                A
# HTHG             NaN
# HTAG             NaN
# HTR              NaN
# Season       1993-94
# Name: 0, dtype: object

# %%
# First of all, we need to list all games on season 93-94.
# Once all games been list, we can start finding something nice during that season.

epl_data.loc[epl_data.Season == '1993-94']
# Out:
#     Div      Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  14/08/93         Arsenal        Coventry     0     3   A   NaN   NaN
# 1    E0  14/08/93     Aston Villa             QPR     4     1   H   NaN   NaN
# 2    E0  14/08/93         Chelsea       Blackburn     1     2   A   NaN   NaN
# 3    E0  14/08/93       Liverpool  Sheffield Weds     2     0   H   NaN   NaN
# 4    E0  14/08/93        Man City           Leeds     1     1   D   NaN   NaN
# ..   ..       ...             ...             ...   ...   ...  ..   ...   ...
# 457  E0  7/5/1994  Sheffield Weds        Man City     1     1   D   NaN   NaN
# 458  E0  7/5/1994         Swindon           Leeds     0     5   A   NaN   NaN
# 459  E0  7/5/1994       Tottenham             QPR     1     2   A   NaN   NaN
# 460  E0  7/5/1994        West Ham     Southampton     3     3   D   NaN   NaN
# 461  E0  8/5/1994      Man United        Coventry     0     0   D   NaN   NaN
#
#      HTR   Season
# ...

# %%
# As you can see first match on 93/94 season are on 14/8/93 and end on 8/5/94
# Okay, now we start to determine what we want first.
# I start analyst my favourite team "Arsenal"

epl_data.HomeTeam[(epl_data.Season == "1993-94") & (epl_data.HomeTeam == "Arsenal") ]

# Below list of match that Arsenal play on season 93/94
# Out:
# 0      Arsenal
# 34     Arsenal
# 45     Arsenal
# 66     Arsenal
# 88     Arsenal
# 110    Arsenal
# 132    Arsenal
# 143    Arsenal
# 175    Arsenal
# 197    Arsenal
# 214    Arsenal
# 240    Arsenal
# 257    Arsenal
# 275    Arsenal
# 313    Arsenal
# 356    Arsenal
# 358    Arsenal
# 376    Arsenal
# 405    Arsenal
# 416    Arsenal
# 434    Arsenal
# Name: HomeTeam, dtype: object

# %%
epl_data.HomeTeam[(epl_data.Season == "1993-94") & (epl_data.HomeTeam == "Arsenal") ].count()
# Arsenal play 21 home game on this 93/94 season
# Bored with Arsenal right?

epl_data9394 = epl_data.HomeTeam[(epl_data.Season == "1993-94") & (epl_data.HomeTeam == "Arsenal") ].count()

print(epl_data9394)
# Out:
# 21

# %%
# Next !!! We are gonna start visualize all 93/94 insights
epl_data.loc[epl_data.Season == '1993-94']

epl_data9394 = epl_data.loc[epl_data.Season == '1993-94']

# %%
# We try to visualize all home goal for 93/04 season
# Its still messy and doesnt show a lot 

plt.figure(figsize=(20,6))

# Add title
plt.title("Full time Home goal")

# Line chart showing all Home goal'
sns.lineplot(data=epl_data9394['FTHG'], label="FTHG")



# Add label for horizontal axis
plt.xlabel("Match Id")
# Out:
# Text(0.5, 0, 'Match Id')

# %%
# We try to visualize all away goal for 93/04 season
# Its still messy and doesnt show a lot 

plt.figure(figsize=(20,6))

# Add title
plt.title("Full time Away goal")

# Line chart showing all Away goal'
sns.lineplot(data=epl_data9394['FTAG'], label="FTAG")



# Add label for horizontal axis
plt.xlabel("Match Id")
# Out:
# Text(0.5, 0, 'Match Id')

# %%
# We calculate home goal during 93/94 season
epl_data.HomeTeam[(epl_data.Season == "1993-94") & (epl_data.FTHG) ].count()
# Out:
# 231

# %%
# We calculate away goal during 93/94 season
epl_data.AwayTeam[(epl_data.Season == "1993-94") & (epl_data.FTAG) ].count()
# Out:
# 204

# %%
# Result of home and away shows that home team during 93/94 season show a more determination
# to score compare to away team

# %%
# We try to visualize all away & home goal for 93/04 season
# Its still messy and doesnt show a lot 

plt.figure(figsize=(20,6))

# Add title
plt.title("Full time Away & Home goal")

# Line chart showing all Away goal'
sns.lineplot(data=epl_data9394['FTAG'], label="FTAG")
sns.lineplot(data=epl_data9394['FTHG'], label="FTHG")


# Add label for horizontal axis
plt.xlabel("Match Id")

# But we know total for Home goal and Away goal
# Total goal will be 435 goals in that 93/94 season
# Out:
# Text(0.5, 0, 'Match Id')

# %%
# From the graph we can see that we have match that Home goal are more than 6
# That is quite a lot, so we try to find which match

epl_data.HomeTeam[(epl_data.Season == "1993-94") & (epl_data.FTHG > 6) ]
# Out:
# 336    Newcastle
# Name: HomeTeam, dtype: object

# %%
# It is match 336 between Newcastle vs ?????
epl_data.iloc[336]
# Out:
# Div                E0
# Date        12/3/1994
# HomeTeam    Newcastle
# AwayTeam      Swindon
# FTHG                7
# FTAG                1
# FTR                 H
# HTHG              NaN
# HTAG              NaN
# HTR               NaN
# Season        1993-94
# Name: 336, dtype: object

# %%
# From the graph we can see that we have match that Home goal are more than 4
# That is quite a lot, so we try to find which match

epl_data.AwayTeam[(epl_data.Season == "1993-94") & (epl_data.FTAG > 4)]
# Out:
# 32       Liverpool
# 92         Norwich
# 244     Man United
# 325        Arsenal
# 400    Southampton
# 458          Leeds
# Name: AwayTeam, dtype: object

# %%
# It is match 32,92,244,325,400,458 between as per show vs ?????
epl_data.iloc[32]
# Out:
# Div                E0
# Date         22/08/93
# HomeTeam      Swindon
# AwayTeam    Liverpool
# FTHG                0
# FTAG                5
# FTR                 A
# HTHG              NaN
# HTAG              NaN
# HTR               NaN
# Season        1993-94
# Name: 32, dtype: object

# %%
# It is match 32,92,244,325,400,458 between as per show vs ?????
epl_data.iloc[92]
# Out:
# Div               E0
# Date        25/09/93
# HomeTeam     Everton
# AwayTeam     Norwich
# FTHG               1
# FTAG               5
# FTR                A
# HTHG             NaN
# HTAG             NaN
# HTR              NaN
# Season       1993-94
# Name: 92, dtype: object

# %%
# It is match 32,92,244,325,400,458 between as per show vs ?????
epl_data.iloc[244]
# Out:
# Div                 E0
# Date          29/12/93
# HomeTeam        Oldham
# AwayTeam    Man United
# FTHG                 2
# FTAG                 5
# FTR                  A
# HTHG               NaN
# HTAG               NaN
# HTR                NaN
# Season         1993-94
# Name: 244, dtype: object

# %%
# I think 3 match are enough. Tired too paste more..hahaha
# Finish with 93/94 season.
# Will continue next season if i get more upvote
# Thanks and hope everyone enjoy.
